# %% [markdown]
# ##### BAIS 3250 Project Webscrape
# ##### IMDb Movie Data Web Scraping
# ###### May 9, 2025
# ###### Ella Solie

# %% [markdown]
# ###### Import libraries

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
import random
import requests
import re

# %% [markdown]
# ###### Open IMDb movie dataset URL

# %%
options = webdriver.ChromeOptions()
options.headless = True  # Run in headless mode (no browser UI)
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# URL for IMDb movie list
url = "https://www.imdb.com/list/ls026212430/"

# Open the URL
driver.get(url)
time.sleep(random.uniform(5, 10))  # Wait for the page to load

# %% [markdown]
# ###### Create lists to store extracted data. Extract data from movie dataset.

# %%
imdb_ids, titles, ratings, years, votes, durations, movie_ratings = [], [], [], [], [], [], []  # Renamed variable for movie ratings

while True:  # Loop through pages
    # Extract movie elements
    movies = driver.find_elements(By.CLASS_NAME, "ipc-metadata-list-summary-item")

    for movie in movies:
        # Extract IMDb ID from href
        try:
            link = movie.find_element(By.TAG_NAME, 'a').get_attribute('href')
            imdb_id = link.split('/')[4]  # e.g., /title/tt1234567/
            imdb_ids.append(imdb_id)
        except:
            imdb_ids.append(None)
        # Extract title
        try:
            title = movie.find_element(By.CLASS_NAME, "ipc-title__text").text
            titles.append(title)
        except:
            titles.append(None)

        # Extract IMDb star rating
        try:
            rating = movie.find_element(By.CLASS_NAME, "ipc-rating-star--rating").text
            ratings.append(float(rating))
        except:
            ratings.append(None)

        # Extract vote count
        try:
            vote_text = movie.find_element(By.XPATH, ".//span[contains(@class, 'voteCount')]").text
            vote_text = vote_text.replace("(", "").replace(")", "")
            if 'M' in vote_text:
                vote_text = vote_text.replace('M', '').strip()
                votes.append(int(float(vote_text) * 1_000_000))
            elif 'K' in vote_text:
                vote_text = vote_text.replace('K', '').strip()
                votes.append(int(float(vote_text) * 1_000))
            else:
                votes.append(int(vote_text.replace(",", "").strip()))
        except:
            votes.append(None)

        # Extract year
        try:
            year_text = movie.find_element(By.XPATH, ".//span[contains(@class, 'dli-title')]").text
            years.append(year_text)
        except:
            years.append(None)

        # Extract duration
        try:
            duration_text = movie.find_element(By.XPATH, ".//span[contains(@class, 'metadata-item') and contains(text(), 'm')]").text
            durations.append(duration_text)
        except:
            durations.append(None)
            
        # Extract movie rating
        try:
            movie_rating = movie.find_element(By.XPATH, ".//span[contains(@class, 'metadata-item') and (contains(text(), 'G') or contains(text(), 'PG') or contains(text(), 'PG-13') or contains(text(), 'R') or contains(text(), 'Approved') or contains(text(), 'Not Rated') or contains(text(), 'NC-17'))]").text
            movie_ratings.append(movie_rating)  
        except:
            movie_ratings.append(None)

    # Find the "Next" button 
    try:
        next_buttons = driver.find_elements(By.XPATH, "//button/span[contains(text(), 'Next')]")
        if next_buttons:
            next_button = next_buttons[0]  # Select first match
            driver.execute_script("arguments[0].scrollIntoView();", next_button) 
            time.sleep(random.uniform(2, 5))  # Allow time 
            next_button.click()
            time.sleep(random.uniform(5, 10))  # Wait for new page to load
        else:
            print("No more pages to scrape.")
            break  # Exit loop if there is no "Next" button
    except:
        print("No more pages to scrape.")
        break 

# Close the Chrome browser
driver.quit()

# Save the data to a DataFrame
df = pd.DataFrame({
    "imdb_id": imdb_ids,
    "movie_title": titles,
    "average_star_rating_movie": ratings,
    "release_year_movie": years,
    "vote_count_movie": votes,
    "duration_movie": durations,
    "movie_rating": movie_ratings # Updated list name to match variable
})

print(df)
# Out:
# No more pages to scrape.
#        imdb_id                                        movie_title  \
# 0    tt0109830                                    1. Forrest Gump
# 1    tt0068646                                   2. The Godfather
# 2    tt0120737  3. The Lord of the Rings: The Fellowship of th...
# 3    tt0167260   4. The Lord of the Rings: The Return of the King
# 4    tt0167261           5. The Lord of the Rings: The Two Towers
# ..         ...                                                ...
# 245  tt0092005                                   246. Stand by Me
# 246  tt0061452                                 247. Casino Royale
# 247  tt0381061                                 248. Casino Royale
# 248  tt0360556                                249. Fahrenheit 451
# 249  tt1302006                                  250. The Irishman
#
#      average_star_rating_movie release_year_movie  vote_count_movie  \
# 0                          8.8               1994         2400000.0
# 1                          9.2               1972         2100000.0
# 2                          8.9               2001         2100000.0
# 3                          9.0               2003         2100000.0
# 4                          8.8               2002         1900000.0
# ..                         ...                ...               ...
# 245                        8.1               1986          464000.0
# 246                        5.0               1967           34000.0
# 247                        8.0               2006          717000.0
# 248                        5.0               2018           24000.0
# 249                        7.8               2019          453000.0
#
#     duration_movie movie_rating
# 0           2h 22m        PG-13
# 1           2h 55m            R
# 2           2h 58m        PG-13
# 3           3h 21m        PG-13
# 4           2h 59m        PG-13
# ..             ...          ...
# 245         1h 29m            R
# 246         2h 11m     Approved
# 247         2h 24m        PG-13
# 248         1h 40m         None
# 249         3h 29m            R
#
# [250 rows x 7 columns]

# %%
# Function to scrape the top review from IMDb for a given movie
def scrape_top_review(imdb_id):
    url = f"https://www.imdb.com/title/{imdb_id}/reviews"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)',
        'Accept-Language': 'en-US,en;q=0.9'
    }

    response = requests.get(url, headers=headers)
    html = response.text

    match = re.search(r'<div class="ipc-html-content-inner-div" role="presentation">(.+?)</div>', html, re.DOTALL)
    if match:
        return re.sub(r'<.*?>', '', match.group(1)).strip()
    return None

# Scrape top reviews for all IMDb IDs collected
top_reviews = []

for imdb_id in df['imdb_id']:
    print(f"Scraping first review for {imdb_id}.")
    review = scrape_top_review(imdb_id)
    top_reviews.append(review)
    time.sleep(1.5)  # Be respectful

# Add review column to DataFrame
df['review_text'] = top_reviews

print(df)
# Out:
# Scraping top review for tt0109830...
# Scraping top review for tt0068646...
# Scraping top review for tt0120737...
# Scraping top review for tt0167260...
# Scraping top review for tt0167261...
# Scraping top review for tt0914798...
# Scraping top review for tt0414387...
# Scraping top review for tt0332280...
# Scraping top review for tt0421715...
# Scraping top review for tt0281358...
# Scraping top review for tt0480249...
# Scraping top review for tt0396171...
# Scraping top review for tt0458352...
# Scraping top review for tt0253474...
# Scraping top review for tt0398808...
# Scraping top review for tt0431308...
# Scraping top review for tt1078588...
# Scraping top review for tt0382625...
# Scraping top review for tt0808151...
# Scraping top review for tt3062096...
# Scraping top review for tt0822832...
# Scraping top review for tt0343818...
# Scraping top review for tt0110148...
# Scraping top review for tt0107290...
# Scraping top review for tt0108052...
# Scraping top review for tt1010048...
# Scraping top review for tt0243155...
# Scraping top review for tt0120689...
# Scraping top review for tt0066921...
# Scraping top review for tt0102926...
# Scraping top review for tt0489099...
# Scraping top review for tt0070047...
# Scraping top review for tt0111161...
# Scraping top review for tt0081505...
# Scraping top review for tt0775440...
# Scraping top review for tt0407304...
# Scraping top review for tt0133152...
# Scraping top review for tt0484740...
# Scraping top review for tt0319970...
# Scraping top review for tt0031381...
# Scraping top review for tt0380599...
# Scraping top review for tt0120815...
# Scraping top review for tt0137523...
# Scraping top review for tt0268978...
# Scraping top review for tt0091605...
# Scraping top review for tt0106246...
# Scraping top review for tt0884328...
# Scraping top review for tt0112579...
# Scraping top review for tt1057500...
# Scraping top review for tt0387131...
# Scraping top review for tt1242422...
# Scraping top review for tt1305806...
# Scraping top review for tt0117951...
# Scraping top review for tt0142688...
# Scraping top review for tt0159365...
# Scraping top review for tt0092965...
# Scraping top review for tt0100054...
# Scraping top review for tt0488604...
# Scraping top review for tt0073540...
# Scraping top review for tt0083658...
# Scraping top review for tt0395119...
# Scraping top review for tt0117913...
# Scraping top review for tt0107798...
# Scraping top review for tt0106918...
# Scraping top review for tt0109446...
# Scraping top review for tt0115862...
# Scraping top review for tt0313542...
# Scraping top review for tt0362001...
# Scraping top review for tt0119196...
# Scraping top review for tt0119978...
# Scraping top review for tt3772576...
# Scraping top review for tt3402236...
# Scraping top review for tt1869347...
# Scraping top review for tt0070511...
# Scraping top review for tt0048918...
# Scraping top review for tt0317248...
# Scraping top review for tt0100157...
# Scraping top review for tt0098084...
# Scraping top review for tt0085382...
# Scraping top review for tt0085333...
# Scraping top review for tt3631112...
# Scraping top review for tt0289765...
# Scraping top review for tt0367959...
# Scraping top review for tt0212985...
# Scraping top review for tt0059113...
# Scraping top review for tt0241527...
# Scraping top review for tt0330373...
# Scraping top review for tt0295297...
# Scraping top review for tt1392170...
# Scraping top review for tt1951264...
# Scraping top review for tt1951266...
# Scraping top review for tt1951265...
# Scraping top review for tt4500922...
# Scraping top review for tt1790864...
# Scraping top review for tt4046784...
# Scraping top review for tt1099212...
# Scraping top review for tt1673434...
# Scraping top review for tt1324999...
# Scraping top review for tt1259571...
# Scraping top review for tt1325004...
# Scraping top review for tt0112641...
# Scraping top review for tt0113627...
# Scraping top review for tt0095953...
# Scraping top review for tt1600196...
# Scraping top review for tt0144214...
# Scraping top review for tt1741273...
# Scraping top review for tt1677720...
# Scraping top review for tt0758758...
# Scraping top review for tt0454876...
# Scraping top review for tt0878804...
# Scraping top review for tt0289879...
# Scraping top review for tt0172493...
# Scraping top review for tt1045658...
# Scraping top review for tt0112573...
# Scraping top review for tt0120669...
# Scraping top review for tt0276751...
# Scraping top review for tt0062622...
# Scraping top review for tt1334260...
# Scraping top review for tt2267998...
# Scraping top review for tt0107623...
# Scraping top review for tt0068909...
# Scraping top review for tt3954876...
# Scraping top review for tt0285531...
# Scraping top review for tt4413338...
# Scraping top review for tt3721072...
# Scraping top review for tt1753813...
# Scraping top review for tt1001508...
# Scraping top review for tt0458076...
# Scraping top review for tt3859076...
# Scraping top review for tt1605777...
# Scraping top review for tt3741834...
# Scraping top review for tt3202202...
# Scraping top review for tt4214530...
# Scraping top review for tt0467200...
# Scraping top review for tt1702439...
# Scraping top review for tt0810819...
# Scraping top review for tt4924942...
# Scraping top review for tt2334733...
# Scraping top review for tt4228816...
# Scraping top review for tt3170832...
# Scraping top review for tt1667355...
# Scraping top review for tt1726592...
# Scraping top review for tt1599975...
# Scraping top review for tt3577624...
# Scraping top review for tt4025514...
# Scraping top review for tt0959337...
# Scraping top review for tt1929263...
# Scraping top review for tt0900387...
# Scraping top review for tt1698641...
# Scraping top review for tt2402101...
# Scraping top review for tt5198884...
# Scraping top review for tt2463512...
# Scraping top review for tt3316960...
# Scraping top review for tt2711898...
# Scraping top review for tt6522634...
# Scraping top review for tt2884018...
# Scraping top review for tt0338467...
# Scraping top review for tt0077413...
# Scraping top review for tt0090156...
# Scraping top review for tt0051201...
# Scraping top review for tt0083908...
# Scraping top review for tt0089640...
# Scraping top review for tt0055205...
# Scraping top review for tt0060094...
# Scraping top review for tt0054802...
# Scraping top review for tt0058383...
# Scraping top review for tt0090914...
# Scraping top review for tt0991347...
# Scraping top review for tt0061075...
# Scraping top review for tt0029171...
# Scraping top review for tt0339716...
# Scraping top review for tt0445570...
# Scraping top review for tt0113249...
# Scraping top review for tt0037515...
# Scraping top review for tt0094669...
# Scraping top review for tt0098454...
# Scraping top review for tt0087852...
# Scraping top review for tt0067052...
# Scraping top review for tt0279250...
# Scraping top review for tt0117282...
# Scraping top review for tt0086287...
# Scraping top review for tt0103078...
# Scraping top review for tt0244901...
# Scraping top review for tt0075214...
# Scraping top review for tt0073247...
# Scraping top review for tt0071566...
# Scraping top review for tt0062863...
# Scraping top review for tt0251114...
# Scraping top review for tt0089572...
# Scraping top review for tt0113501...
# Scraping top review for tt0086442...
# Scraping top review for tt0093966...
# Scraping top review for tt0087089...
# Scraping top review for tt1340800...
# Scraping top review for tt0059749...
# Scraping top review for tt1972571...
# Scraping top review for tt0087629...
# Scraping top review for tt1995390...
# Scraping top review for tt0061556...
# Scraping top review for tt0236784...
# Scraping top review for tt0066001...
# Scraping top review for tt0102485...
# Scraping top review for tt0100530...
# Scraping top review for tt1205537...
# Scraping top review for tt0164184...
# Scraping top review for tt0158423...
# Scraping top review for tt0114691...
# Scraping top review for tt0109444...
# Scraping top review for tt0105112...
# Scraping top review for tt0099810...
# Scraping top review for tt0077610...
# Scraping top review for tt0311113...
# Scraping top review for tt0465537...
# Scraping top review for tt0369059...
# Scraping top review for tt1189340...
# Scraping top review for tt0309377...
# Scraping top review for tt2990756...
# Scraping top review for tt3622592...
# Scraping top review for tt2582846...
# Scraping top review for tt2674426...
# Scraping top review for tt0478087...
# Scraping top review for tt0099731...
# Scraping top review for tt2322441...
# Scraping top review for tt4465564...
# Scraping top review for tt4477536...
# Scraping top review for tt1840309...
# Scraping top review for tt3410834...
# Scraping top review for tt2908446...
# Scraping top review for tt0037913...
# Scraping top review for tt0052618...
# Scraping top review for tt0041959...
# Scraping top review for tt0062622...
# Scraping top review for tt0040897...
# Scraping top review for tt0055928...
# Scraping top review for tt0084787...
# Scraping top review for tt0032138...
# Scraping top review for tt0057115...
# Scraping top review for tt0073486...
# Scraping top review for tt0070510...
# Scraping top review for tt0119488...
# Scraping top review for tt1659337...
# Scraping top review for tt0063442...
# Scraping top review for tt0056592...
# Scraping top review for tt0093779...
# Scraping top review for tt1130884...
# Scraping top review for tt0092005...
# Scraping top review for tt0061452...
# Scraping top review for tt0381061...
# Scraping top review for tt0360556...
# Scraping top review for tt1302006...
#        imdb_id                                        movie_title  \
# 0    tt0109830                                    1. Forrest Gump
# 1    tt0068646                                   2. The Godfather
# 2    tt0120737  3. The Lord of the Rings: The Fellowship of th...
# 3    tt0167260   4. The Lord of the Rings: The Return of the King
# 4    tt0167261           5. The Lord of the Rings: The Two Towers
# ..         ...                                                ...
# 245  tt0092005                                   246. Stand by Me
# 246  tt0061452                                 247. Casino Royale
# 247  tt0381061                                 248. Casino Royale
# 248  tt0360556                                249. Fahrenheit 451
# 249  tt1302006                                  250. The Irishman
#
#      average_star_rating_movie release_year_movie  vote_count_movie  \
# 0                          8.8               1994         2400000.0
# 1                          9.2               1972         2100000.0
# 2                          8.9               2001         2100000.0
# 3                          9.0               2003         2100000.0
# 4                          8.8               2002         1900000.0
# ..                         ...                ...               ...
# 245                        8.1               1986          464000.0
# 246                        5.0               1967           34000.0
# 247                        8.0               2006          717000.0
# 248                        5.0               2018           24000.0
# 249                        7.8               2019          453000.0
#
#     duration_movie movie_rating  \
# 0           2h 22m        PG-13
# 1           2h 55m            R
# 2           2h 58m        PG-13
# 3           3h 21m        PG-13
# 4           2h 59m        PG-13
# ..             ...          ...
# 245         1h 29m            R
# 246         2h 11m     Approved
# 247         2h 24m        PG-13
# 248         1h 40m         None
# 249         3h 29m            R
#
#                                            review_text
# 0    When I first saw this movie I didn&#39;t appre...
# 1    It is now past 1 PM and I just finished watchi...
# 2    Simply incredible. Never before have I seen a ...
# 3    This movie, and trilogy in general, is a cinem...
# 4    Peter Jackson truly outdid himself when creati...
# ..                                                 ...
# 245  If you grew up in the world before WiFi, a hig...
# 246  Casino Royale has some outstanding elements. T...
# 247  I distinctly remember the collective groan fro...
# 248  ...I&#39;ll keep this brief.Bradbury would not...
# 249  I don&#39;t know where to start on this one ot...
#
# [250 rows x 8 columns]

# %% [markdown]
# ###### Save the dataframe to CSV file

# %%
df.to_csv("esolie_bais3250_project_webscrape_imdb.csv", index=False, encoding='utf-8')
